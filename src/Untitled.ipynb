# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '0.25.3'

# %%
df = pd.read_stata('../data/554-Modulo1116/Capitulo_I_NACIONAL.dta')

# %%
df
# Out:
#           ID CCDD DEPARTAMENTO CCPP   PROVINCIA CCDI    DISTRITO  NO_DISPONE  \
# 0       0001   01     AMAZONAS   02       BAGUA   02    ARAMANGO         1.0
# 1       0002   01     AMAZONAS   02       BAGUA   01       BAGUA         1.0
# 2     0005-A   01     AMAZONAS   02       BAGUA   05       IMAZA         1.0
# 3       0005   01     AMAZONAS   02       BAGUA   05       IMAZA         1.0
# 4       0008   01     AMAZONAS   02       BAGUA   06     LA PECA         1.0
# ...      ...  ...          ...  ...         ...  ...         ...         ...
# 2607    4204   25      UCAYALI   03  PADRE ABAD   01  PADRE ABAD         1.0
# 2608  4204-A   25      UCAYALI   03  PADRE ABAD   01  PADRE ABAD         1.0
# 2609    4205   25      UCAYALI   03  PADRE ABAD   01  PADRE ABAD         1.0
# 2610    4206   25      UCAYALI   03  PADRE ABAD   01  PADRE ABAD         1.0
# 2611    4212   25      UCAYALI   04       PURUS   01       PURUS         1.0
#
# ...

# %%
df.describe()
# Out:
#        NO_DISPONE         PISO
# count      2612.0  2612.000000
# mean          1.0     1.014165
# std           0.0     0.136257
# min           1.0     1.000000
# 25%           1.0     1.000000
# 50%           1.0     1.000000
# 75%           1.0     1.000000
# max           1.0     4.000000

# %%
df.dtypes
# Out:
# ID                object
# CCDD              object
# DEPARTAMENTO      object
# CCPP              object
# PROVINCIA         object
# CCDI              object
# DISTRITO          object
# NO_DISPONE       float64
# GPS_LON           object
# GPS_LAT           object
# GPS_ALT           object
# TIPO_VIA        category
# NOM_VIA           object
# NRO_PUERTA        object
# BLOCK             object
# INTERIOR          object
# PISO             float64
# MZ                object
# LOTE              object
# KM                object
# REFERENCIA        object
# dtype: object

# %%
df[['GPS_LON','GPS_LAT']]
# Out:
#          GPS_LON     GPS_LAT
# 0      -78,43725   -5,417803
# 1     -78,436642   -5,610554
# 2     -78,537126   -5,639338
# 3     -78,288595   -5,162497
# 4     -78,533095  -5,6313229
# ...          ...         ...
# 2607  -75,508787   -9,036991
# 2608  -75,508272   -9,035854
# 2609  -75,515672   -9,051781
# 2610  -75,446262   -8,977097
# 2611  -70,709565   -9,772091
#
# [2612 rows x 2 columns]

# %%
df_markets =
